# %%
display(dbutils.secrets.listScopes())

# %%
from databricks.sdk import WorkspaceClient
w = WorkspaceClient()
w.secrets.put_secret(
    scope = "kv-cenomi",
    key = "datalakeemailpassword",
    string_value = "qyqk atyx rzof deyk"
)

# %%
from app import create_tabular_card_readable
df = spark.sql("select * from dev.bronze.employee")
create_tabular_card_readable(df, "Employee Preview", limit_rows=20)
